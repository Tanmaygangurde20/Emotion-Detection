# %% [markdown]
# # Emotion Detection from scratch

# %% [markdown]
# # Installing Packages

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import imghdr
import tensorflow as tf
from PIL import Image


from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.utils.class_weight import compute_class_weight

from tensorflow.keras import layers, models, regularizers, optimizers
from tensorflow.keras.applications import VGG16, ResNet50V2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard, CSVLogger
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten, Dense, Activation, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.utils import plot_model
# Out:
# C:\Users\tanma\AppData\Local\Temp\ipykernel_15412\3707579433.py:7: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   import imghdr
# WARNING:tensorflow:From c:\Users\tanma\anaconda3\envs\emenv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Setting up Directory to save model data.

# %%
os.makedirs('test_dir', exist_ok=True)

# %%
# Define your project name
project_name = 'FER_2013_Emotion_Detection'

# List your models
model_names = [
    'Custom_CNN_From_Scratch',
    'Custom_CNN_With_Augmentation',
    'VGG16_Transfer_Learning',
    'ResNet50_Transfer_Learning'
]

# Base directory (in this case, your Google Colab workspace)
base_dir = 'D:/VS CODE/Notebook/Dataset/Emotion/'

# Create the project directory
project_dir = os.path.join(base_dir, project_name)
os.makedirs(project_dir, exist_ok=True)

# Create a subdirectory for each model
for each_model in model_names:
    model_dir = os.path.join(project_dir, each_model)
    os.makedirs(model_dir, exist_ok=True)
    # Example subdirectories for model-related files
    # os.makedirs(os.path.join(model_dir, 'checkpoints'), exist_ok=True)
    # os.makedirs(os.path.join(model_dir, 'logs'), exist_ok=True)
    # os.makedirs(os.path.join(model_dir, 'saved_models'), exist_ok=True)

print(f'Project directory structure created at: {project_dir}')
# Out:
# Project directory structure created at: D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection

# %% [markdown]
# # Data Cleaning

# %%
# Define the list of acceptable image extensions
image_exts = ['jpeg', 'jpg', 'png']

# Path to the directory containing image classes and possibly other nested subdirectories
data_dir = 'D:/VS CODE/Notebook/Dataset/Emotion/train'

# Walk through all directories and files in the dataset
for root, dirs, files in os.walk(data_dir):
    for file in files:
        # Construct the path to the current file
        file_path = os.path.join(root, file)

        try:
            # Check the file type of the current file
            file_type = imghdr.what(file_path)

            # If the file extension is not in the allowed list, remove it
            if file_type not in image_exts:
                print(f'Image not in ext list {file_path}')
                os.remove(file_path)
            else:
                # Proceed to process the image if needed, for example, reading it with OpenCV
                img = cv2.imread(file_path)

        except Exception as e:
            # Print out the issue and the path of the problematic file
            print(f'Issue with file {file_path}. Error: {e}')
            # Optionally, remove files that cause exceptions
            os.remove(file_path)

# %% [markdown]
# # Data Analysis

# %%
# Define a function to count the number of files (assumed to be images for this context) for each subdirectory in a given directory.
# The function returns a DataFrame with these counts, indexed by a specified set name (e.g., 'train' or 'test').
def count_files_in_subdirs(directory, set_name):
    # Initialize an empty dictionary to hold the count of files for each subdirectory.
    counts = {}

    # Iterate over each item in the given directory.
    for item in os.listdir(directory):
        # Construct the full path to the item.
        item_path = os.path.join(directory, item)

        # Check if the item is a directory.
        if os.path.isdir(item_path):
            # Count the number of files in the subdirectory and add it to the dictionary.
            counts[item] = len(os.listdir(item_path))

    # Convert the counts dictionary to a DataFrame for easy viewing and analysis.
    # The index of the DataFrame is set to the provided set name.
    df = pd.DataFrame(counts, index=[set_name])
    return df

# Paths to the training and testing directories.
train_dir = 'D:/VS CODE/Notebook/Dataset/Emotion/train'
test_dir = 'D:/VS CODE/Notebook/Dataset/Emotion/test'

# Count the files in the subdirectories of the training directory and print the result.
train_count = count_files_in_subdirs(train_dir, 'train')
print(train_count)

# Count the files in the subdirectories of the testing directory and print the result.
test_count = count_files_in_subdirs(test_dir, 'test')
print(test_count)
# Out:
#        angry  disgust  fear  happy  neutral   sad  surprise
# train   3995      436  4097   7215     4965  4830      3171
#       angry  disgust  fear  happy  neutral   sad  surprise
# test    958      111  1024   1774     1233  1247       831

# %%
train_count.transpose().plot(kind='bar')
# Out:
# <Axes: >

# %%
test_count.transpose().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Plotting one image from each emotion.

# %%
emotions = os.listdir(train_dir)
plt.figure(figsize=(15,10))

for i, emotion in enumerate(emotions, 1):
    folder = os.path.join(train_dir, emotion)
    img_path = os.path.join(folder, os.listdir(folder)[42])
    img = plt.imread(img_path)
    plt.subplot(3, 4, i)
    plt.imshow(img, cmap='gray')
    plt.title(emotion)
    plt.axis('off')

# %% [markdown]
# # Plotting random images from given directory

# %%
def plot_images_from_directory(directory_path, class_name, num_images=9):
    # Retrieve list of all file names in the directory
    image_filenames = os.listdir(directory_path)

    # If there are fewer images than requested, we'll just show them all
    if len(image_filenames) < num_images:
        print(f"Only found {len(image_filenames)} images in {directory_path}, displaying them all.")
        num_images = len(image_filenames)

    # Randomly select 'num_images' number of file names
    selected_images = random.sample(image_filenames, num_images)

    # Plotting the images
    fig, axes = plt.subplots(3, 3, figsize=(5, 5))  # Adjust the size as needed
    axes = axes.ravel()

    for i, image_file in enumerate(selected_images):
        image_path = os.path.join(directory_path, image_file)
        # image = Image.open(image_path)
        image = load_img(image_path)
        axes[i].imshow(image)
        axes[i].set_title(f"Image: {class_name}")
        axes[i].axis('off')  # Hide the axis

    plt.tight_layout()
    plt.show()

# %%
# Placeholder for the directory path
angry_directory_path = 'D:/VS CODE/Notebook/Dataset/Emotion/train/angry'  # Replace with your directory path
plot_images_from_directory(angry_directory_path, class_name = 'Angry')

# %%
# Placeholder for the directory path
disgust_directory_path = 'D:/VS CODE/Notebook/Dataset/Emotion/train/disgust'  # Replace with your directory path
plot_images_from_directory(disgust_directory_path, class_name = 'Disgust')

# %%
# Placeholder for the directory path
surpirse_directory_path = 'D:/VS CODE/Notebook/Dataset/Emotion/train/surprise'  # Replace with your directory path
plot_images_from_directory(surpirse_directory_path, class_name = 'Surpirse')

# %% [markdown]
# # Checking shapes and channels.

# %%
image = 'D:/VS CODE/Notebook/Dataset/Emotion/train/angry/Training_10118481.jpg'

import cv2

img = cv2.imread(image) # Default load in color format.

# If the image is loaded successfully, print its pixel values
if img is not None:
    # print(img)
    print("Shape:", img.shape)
else:
    print("The image could not be loaded. Please check the path and file permissions.")
# Out:
# Shape: (48, 48, 3)

# %%
import cv2

image_path = 'D:/VS CODE/Notebook/Dataset/Emotion/train/angry/Training_10118481.jpg'

# Load the image in grayscale
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# If the image is loaded successfully, print its pixel values
if img is not None:
    # print(img)
    print("Shape:", img.shape)  # This should now print (48, 48)
else:
    print("The image could not be loaded. Please check the path and file permissions.")
# Out:
# Shape: (48, 48)

# %% [markdown]
# # Model 1 : Custom CNN from Scratch

# %% [markdown]
# ## Initializing the ImageGenerators

# %%
# Define paths to the train and validation directories
train_data_dir = 'D:/VS CODE/Python/Notebook/Dataset/Emotion/train'
test_data_dir = 'D:/VS CODE/Python/Notebook/Dataset/Emotion/test'

# %%
# Set some parameters
img_width, img_height = 48, 48  # Size of images
batch_size = 64
epochs = 10
num_classes = 7  # Update this based on the number of your classes

# %%
# Rescale the pixel values (0-255) to the [0, 1] interval
data_generator = ImageDataGenerator(rescale=1./255,
                                    validation_split=0.2)

# Automatically retrieve images and their classes for train and validation sets
train_generator = data_generator.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    subset='training')

validation_generator = data_generator.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    subset='validation')

test_generator = data_generator.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',)
    # subset='validation')
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Accessing class labels for the training data
train_class_labels = train_generator.class_indices
print("Training class labels:", train_class_labels)

# Accessing class labels for the validation data
validation_class_labels = validation_generator.class_indices
print("Validation class labels:", validation_class_labels)

# Accessing class labels for the validation data
test_class_labels = test_generator.class_indices
print("Validation class labels:", test_class_labels)
# Out:
# Training class labels: {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
# Validation class labels: {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
# Validation class labels: {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}

# %%
# Initialising the CNN
model = Sequential()

# Adding convolutional layers with activations on the same line for clarity
model.add(Conv2D(32, kernel_size=(3, 3),kernel_initializer="glorot_uniform", padding='same', input_shape=(img_width, img_height, 1)))
model.add(Activation('relu'))
model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(Conv2D(256, kernel_size=(3, 3), kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(Conv2D(512, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening and adding dense layers
model.add(Flatten())
model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(num_classes))
model.add(Activation('softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\tanma\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  activation_1 (Activation)   (None, 48, 48, 64)        0
#
#  batch_normalization (Batch  (None, 48, 48, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  activation_2 (Activation)   (None, 24, 24, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 256)       295168
#
#  activation_3 (Activation)   (None, 22, 22, 256)       0
#
#  batch_normalization_1 (Bat  (None, 22, 22, 256)       1024
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 11, 11, 256)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 512)       1180160
#
#  activation_4 (Activation)   (None, 11, 11, 512)       0
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 512)       2359808
#
#  activation_5 (Activation)   (None, 11, 11, 512)       0
#
#  batch_normalization_2 (Bat  (None, 11, 11, 512)       2048
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 5, 512)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 5, 5, 512)         0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 1024)              13108224
#
#  activation_6 (Activation)   (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
#  activation_7 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 17046535 (65.03 MB)
# Trainable params: 17044871 (65.02 MB)
# Non-trainable params: 1664 (6.50 KB)
# _________________________________________________________________

# %%
# Compiling the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  activation_1 (Activation)   (None, 48, 48, 64)        0
#
#  batch_normalization (Batch  (None, 48, 48, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  activation_2 (Activation)   (None, 24, 24, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 256)       295168
#
#  activation_3 (Activation)   (None, 22, 22, 256)       0
#
#  batch_normalization_1 (Bat  (None, 22, 22, 256)       1024
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 11, 11, 256)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 512)       1180160
#
#  activation_4 (Activation)   (None, 11, 11, 512)       0
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 512)       2359808
#
#  activation_5 (Activation)   (None, 11, 11, 512)       0
#
#  batch_normalization_2 (Bat  (None, 11, 11, 512)       2048
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 5, 512)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 5, 5, 512)         0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 1024)              13108224
#
#  activation_6 (Activation)   (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
#  activation_7 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 17046535 (65.03 MB)
# Trainable params: 17044871 (65.02 MB)
# Non-trainable params: 1664 (6.50 KB)
# _________________________________________________________________

# %%
pip install pydot
# Out:
# Collecting pydot
#   Downloading pydot-2.0.0-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: pyparsing>=3 in c:\users\tanma\appdata\local\programs\python\python311\lib\site-packages (from pydot) (3.1.1)
# Downloading pydot-2.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: pydot
# Successfully installed pydot-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
plot_model(model, to_file = 'D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Architecture.png',
           show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # Understanding Callbacks

# %%
# File path for the model checkpoint
cnn_path = 'D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch'
name = 'Custom_CNN_model.keras'
chk_path = os.path.join(cnn_path, name)
chk_path
# Out:
# 'D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\\Custom_CNN_model.keras'

# %%
# Callback to save the model checkpoint
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             monitor='val_loss')

# %%
# Callback for early stopping
earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True)

# %%
# Callback to reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=6,
                              verbose=1,
                              min_delta=0.0001)

# %%
# Callback to log training data to a CSV file
csv_logger = CSVLogger(os.path.join(cnn_path,'training.log'))

# %%
# Aggregating all callbacks into a list
callbacks = [checkpoint, earlystop, reduce_lr, csv_logger]  # Adjusted as per your use-case

# %% [markdown]
# # Calculating Steps for epoch

# %%
train_generator.samples
# Out:
# 22968

# %%
train_steps_per_epoch = train_generator.samples // train_generator.batch_size + 1
validation_steps_epoch = validation_generator.samples // validation_generator.batch_size + 1
test_steps_epoch = test_generator.samples // test_generator.batch_size + 1

# %% [markdown]
# # Model Training

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_steps_per_epoch,
    epochs=20,
    validation_data=validation_generator,
    validation_steps=validation_steps_epoch,
    callbacks=callbacks)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\tanma\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\tanma\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 359/359 [==============================] - ETA: 0s - loss: 12.4533 - accuracy: 0.2800
# Epoch 1: val_loss improved from inf to 11.94385, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 518s 1s/step - loss: 12.4533 - accuracy: 0.2800 - val_loss: 11.9439 - val_accuracy: 0.1785 - lr: 1.0000e-04
# Epoch 2/20
# 359/359 [==============================] - ETA: 0s - loss: 10.2778 - accuracy: 0.3598
# Epoch 2: val_loss improved from 11.94385 to 9.56927, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 410s 1s/step - loss: 10.2778 - accuracy: 0.3598 - val_loss: 9.5693 - val_accuracy: 0.3968 - lr: 1.0000e-04
# Epoch 3/20
# 359/359 [==============================] - ETA: 0s - loss: 8.2885 - accuracy: 0.3996
# Epoch 3: val_loss improved from 9.56927 to 7.41883, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 407s 1s/step - loss: 8.2885 - accuracy: 0.3996 - val_loss: 7.4188 - val_accuracy: 0.4339 - lr: 1.0000e-04
# Epoch 4/20
# 359/359 [==============================] - ETA: 0s - loss: 6.5705 - accuracy: 0.4371
# Epoch 4: val_loss improved from 7.41883 to 5.97761, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 404s 1s/step - loss: 6.5705 - accuracy: 0.4371 - val_loss: 5.9776 - val_accuracy: 0.4088 - lr: 1.0000e-04
# Epoch 5/20
# 359/359 [==============================] - ETA: 0s - loss: 5.1859 - accuracy: 0.4728
# Epoch 5: val_loss improved from 5.97761 to 4.63987, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 404s 1s/step - loss: 5.1859 - accuracy: 0.4728 - val_loss: 4.6399 - val_accuracy: 0.4820 - lr: 1.0000e-04
# Epoch 6/20
# 359/359 [==============================] - ETA: 0s - loss: 4.1193 - accuracy: 0.5042
# Epoch 6: val_loss improved from 4.63987 to 3.66512, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 404s 1s/step - loss: 4.1193 - accuracy: 0.5042 - val_loss: 3.6651 - val_accuracy: 0.5248 - lr: 1.0000e-04
# Epoch 7/20
# 359/359 [==============================] - ETA: 0s - loss: 3.3342 - accuracy: 0.5256
# Epoch 7: val_loss improved from 3.66512 to 3.08259, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 404s 1s/step - loss: 3.3342 - accuracy: 0.5256 - val_loss: 3.0826 - val_accuracy: 0.5159 - lr: 1.0000e-04
# Epoch 8/20
# 359/359 [==============================] - ETA: 0s - loss: 2.7680 - accuracy: 0.5475
# Epoch 8: val_loss improved from 3.08259 to 2.68047, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 402s 1s/step - loss: 2.7680 - accuracy: 0.5475 - val_loss: 2.6805 - val_accuracy: 0.5107 - lr: 1.0000e-04
# Epoch 9/20
# 359/359 [==============================] - ETA: 0s - loss: 2.3351 - accuracy: 0.5735
# Epoch 9: val_loss improved from 2.68047 to 2.21697, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 402s 1s/step - loss: 2.3351 - accuracy: 0.5735 - val_loss: 2.2170 - val_accuracy: 0.5562 - lr: 1.0000e-04
# Epoch 10/20
# 359/359 [==============================] - ETA: 0s - loss: 2.0314 - accuracy: 0.5912
# Epoch 10: val_loss improved from 2.21697 to 2.02376, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 400s 1s/step - loss: 2.0314 - accuracy: 0.5912 - val_loss: 2.0238 - val_accuracy: 0.5574 - lr: 1.0000e-04
# Epoch 11/20
# 359/359 [==============================] - ETA: 0s - loss: 1.8072 - accuracy: 0.6088
# Epoch 11: val_loss improved from 2.02376 to 1.89749, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 399s 1s/step - loss: 1.8072 - accuracy: 0.6088 - val_loss: 1.8975 - val_accuracy: 0.5503 - lr: 1.0000e-04
# Epoch 12/20
# 359/359 [==============================] - ETA: 0s - loss: 1.6274 - accuracy: 0.6306
# Epoch 12: val_loss improved from 1.89749 to 1.70597, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 398s 1s/step - loss: 1.6274 - accuracy: 0.6306 - val_loss: 1.7060 - val_accuracy: 0.5774 - lr: 1.0000e-04
# Epoch 13/20
# 359/359 [==============================] - ETA: 0s - loss: 1.4835 - accuracy: 0.6560
# Epoch 13: val_loss improved from 1.70597 to 1.66783, saving model to D:/VS CODE/Python/Notebook/Dataset/Custom_CNN_From_Scratch\Custom_CNN_model.keras
# 359/359 [==============================] - 398s 1s/step - loss: 1.4835 - accuracy: 0.6560 - val_loss: 1.6678 - val_accuracy: 0.5835 - lr: 1.0000e-04
# Epoch 14/20
# 348/359 [============================>.] - ETA: 11s - loss: 1.3708 - accuracy: 0.6771

# %% [markdown]
# #### Plotting Performance Metrics

# %%
def plot_training_history(history):
    """
    Plots the training and validation accuracy and loss.

    Parameters:
    - history: A Keras History object. Contains the logs from the training process.

    Returns:
    - None. Displays the matplotlib plots for training/validation accuracy and loss.
    """
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(len(acc))

    plt.figure(figsize=(20, 5))

    # Plot training and validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')

    plt.show()

# %%
plot_training_history(history)

# %% [markdown]
# # Model Evaluation

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 359/359 [==============================] - 10s 28ms/step - loss: 1.8045 - accuracy: 0.6311
# 113/113 [==============================] - 3s 27ms/step - loss: 2.0106 - accuracy: 0.5552
# final train accuracy = 63.11 , validation accuracy = 55.52

# %% [markdown]
# # Plotting Confusion Matrix

# %%
# Assuming your true_classes and predicted_classes are already defined
true_classes = test_generator.classes
predicted_classes = np.argmax(model.predict(test_generator, steps=np.ceil(test_generator.samples/test_generator.batch_size)), axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plotting with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 113/113 [==============================] - 4s 35ms/step

# %%
# Printing the classification report
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.12      0.11      0.11       958
#      disgust       0.00      0.00      0.00       111
#         fear       0.15      0.04      0.06      1024
#        happy       0.25      0.25      0.25      1774
#      neutral       0.18      0.17      0.17      1233
#          sad       0.17      0.30      0.22      1247
#     surprise       0.10      0.12      0.11       831
#
#     accuracy                           0.18      7178
#    macro avg       0.14      0.14      0.13      7178
# weighted avg       0.17      0.18      0.17      7178

# %% [markdown]
# # Making Predictions

# %%
# Emotion classes for the dataset
Emotion_Classes = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# Assuming test_generator and model are already defined
batch_size = test_generator.batch_size

# Selecting a random batch from the test generator
Random_batch = np.random.randint(0, len(test_generator) - 1)

# Selecting random image indices from the batch
Random_Img_Index = np.random.randint(0, batch_size, 10)

# Setting up the plot
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(10, 5),
                         subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    # Fetching the random image and its label
    Random_Img = test_generator[Random_batch][0][Random_Img_Index[i]]
    Random_Img_Label = np.argmax(test_generator[Random_batch][1][Random_Img_Index[i]], axis=0)

    # Making a prediction using the model
    Model_Prediction = np.argmax(model.predict(tf.expand_dims(Random_Img, axis=0), verbose=0), axis=1)[0]

    # Displaying the image
    ax.imshow(Random_Img.squeeze(), cmap='gray')  # Assuming the images are grayscale
    # Setting the title with true and predicted labels, colored based on correctness
    color = "green" if Emotion_Classes[Random_Img_Label] == Emotion_Classes[Model_Prediction] else "red"
    ax.set_title(f"True: {Emotion_Classes[Random_Img_Label]}\nPredicted: {Emotion_Classes[Model_Prediction]}", color=color)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Model 2: Image Augmentation

# %%
# Define paths to the train and validation directories
train_data_dir = '/content/train'
test_data_dir = '/content/test'
# validation_data_dir = '/content/emotion_detection_project/datasets/raw/test'

# Set some parameters
img_width, img_height = 48, 48  # Size of images
batch_size = 64
epochs = 10
num_classes = 7  # Update this based on the number of your classes


# Initializing the ImageDataGenerator with data augmentation options for the training set
data_generator = ImageDataGenerator(
    rescale=1./255,  # Rescale the pixel values from [0, 255] to [0, 1]
    rotation_range=40,  # Degree range for random rotations
    width_shift_range=0.2,  # Range (as a fraction of total width) for random horizontal shifts
    height_shift_range=0.2,  # Range (as a fraction of total height) for random vertical shifts
    shear_range=0.2,  # Shearing intensity (shear angle in counter-clockwise direction)
    zoom_range=0.2,  # Range for random zoom
    horizontal_flip=True,  # Randomly flip inputs horizontally
    fill_mode='nearest',  # Strategy to fill newly created pixels, which can appear after a rotation or a width/height shift
    validation_split=0.2  # Set the validation split; 20% of the data will be used for validation
)

test_data_generator = ImageDataGenerator(rescale=1./255)


# Automatically retrieve images and their classes for train and validation sets
train_generator = data_generator.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    subset='training')

validation_generator = data_generator.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    subset='validation')

test_generator = test_data_generator.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale'
    )
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Path to your specific image
image_path = '/content/train/angry/Training_10118481.jpg'

# Load and convert the image to an array
img = load_img(image_path, color_mode='grayscale', target_size=(img_width, img_height))  # Adjust color_mode if necessary
img_array = img_to_array(img)  # Converts the image to a numpy array
img_array = img_array.reshape((1,) + img_array.shape)  # Reshapes the image to (1, width, height, channels) for the generator

# Setting up the plot
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(10, 4))
# Plot the original image first. Since img_array is a 3D array after reshaping, we use [:, :, 0]
axes[0].imshow(img_array[0, :, :, 0], cmap='gray')
axes[0].set_title('Original Image')
axes[0].axis('off')

# Generate and plot augmented images
for i, ax in enumerate(axes.flat[1:]):  # Start from the second subplot
    # Generate a batch of augmented images
    aug_iter = data_generator.flow(img_array, batch_size=1)
    aug_img = next(aug_iter)[0]  # Get the first augmented image from the batch

    # Plot the augmented image. We directly use [:, :, 0] without an initial batch index
    ax.imshow(aug_img[:, :, 0], cmap='gray')
    ax.set_title(f'Augmented Image {i+1}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Same CNN Model as above

# %%
# Assuming img_width, img_height, and classes are defined. For example:
img_width, img_height = 48, 48
classes = 7

#Initialising the CNN
model = tf.keras.models.Sequential()

# Adding convolutional layers with activations on separate lines
model.add(Conv2D(32, kernel_size=(3, 3), padding='same', input_shape=(img_width, img_height, 1)))
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(tf.keras.layers.Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv2D(256, kernel_size=(3, 3), kernel_regularizer=regularizers.l2(0.01)))
model.add(tf.keras.layers.Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv2D(512, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(tf.keras.layers.Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening and adding dense layers
model.add(Flatten())
model.add(Dense(1024))
model.add(tf.keras.layers.Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(classes))
model.add(tf.keras.layers.Activation('softmax'))

# Compiling the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])


# File path for the model checkpoint
cnn_path = '/content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation'
name = 'Custom_CNN_augmented_model.keras'
chk_path = os.path.join(cnn_path, name)

# Callback to save the model checkpoint
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             monitor='val_loss')

# Callback for early stopping
earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True)

# Callback to reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=6,
                              verbose=1,
                              min_delta=0.0001)

# Callback to log training data to a CSV file
csv_logger = CSVLogger(os.path.join(cnn_path,'training.log'))

# Aggregating all callbacks into a list
callbacks = [checkpoint, earlystop, reduce_lr, csv_logger]  # Adjusted as per your use-case

train_steps_per_epoch = train_generator.samples // train_generator.batch_size + 1
validation_steps_epoch = validation_generator.samples // validation_generator.batch_size + 1
test_steps_epoch = test_generator.samples // test_generator.batch_size + 1

history = model.fit(
    train_generator,
    steps_per_epoch=train_steps_per_epoch,
    epochs=100,
    validation_data=validation_generator,
    validation_steps=validation_steps_epoch,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 359/359 [==============================] - ETA: 0s - loss: 12.4896 - accuracy: 0.2188
# Epoch 1: val_loss improved from inf to 14.14767, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 37s 87ms/step - loss: 12.4896 - accuracy: 0.2188 - val_loss: 14.1477 - val_accuracy: 0.1681 - lr: 1.0000e-04
# Epoch 2/100
# 359/359 [==============================] - ETA: 0s - loss: 10.2419 - accuracy: 0.2406
# Epoch 2: val_loss improved from 14.14767 to 10.43937, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 32s 90ms/step - loss: 10.2419 - accuracy: 0.2406 - val_loss: 10.4394 - val_accuracy: 0.2284 - lr: 1.0000e-04
# Epoch 3/100
# 359/359 [==============================] - ETA: 0s - loss: 8.1725 - accuracy: 0.2461
# Epoch 3: val_loss improved from 10.43937 to 7.88726, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 31s 87ms/step - loss: 8.1725 - accuracy: 0.2461 - val_loss: 7.8873 - val_accuracy: 0.2439 - lr: 1.0000e-04
# Epoch 4/100
# 359/359 [==============================] - ETA: 0s - loss: 6.3900 - accuracy: 0.2496
# Epoch 4: val_loss improved from 7.88726 to 6.55996, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 32s 90ms/step - loss: 6.3900 - accuracy: 0.2496 - val_loss: 6.5600 - val_accuracy: 0.2555 - lr: 1.0000e-04
# Epoch 5/100
# 359/359 [==============================] - ETA: 0s - loss: 4.9852 - accuracy: 0.2593
# Epoch 5: val_loss improved from 6.55996 to 4.91589, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 32s 89ms/step - loss: 4.9852 - accuracy: 0.2593 - val_loss: 4.9159 - val_accuracy: 0.2595 - lr: 1.0000e-04
# Epoch 6/100
# 359/359 [==============================] - ETA: 0s - loss: 3.9425 - accuracy: 0.2672
# Epoch 6: val_loss improved from 4.91589 to 3.85648, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 32s 90ms/step - loss: 3.9425 - accuracy: 0.2672 - val_loss: 3.8565 - val_accuracy: 0.2555 - lr: 1.0000e-04
# Epoch 7/100
# 359/359 [==============================] - ETA: 0s - loss: 3.2123 - accuracy: 0.2734
# Epoch 7: val_loss improved from 3.85648 to 2.92475, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 31s 86ms/step - loss: 3.2123 - accuracy: 0.2734 - val_loss: 2.9248 - val_accuracy: 0.2757 - lr: 1.0000e-04
# Epoch 8/100
# 359/359 [==============================] - ETA: 0s - loss: 2.7132 - accuracy: 0.2847
# Epoch 8: val_loss improved from 2.92475 to 2.50497, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 33s 91ms/step - loss: 2.7132 - accuracy: 0.2847 - val_loss: 2.5050 - val_accuracy: 0.2958 - lr: 1.0000e-04
# Epoch 9/100
# 359/359 [==============================] - ETA: 0s - loss: 2.3783 - accuracy: 0.2999
# Epoch 9: val_loss improved from 2.50497 to 2.25481, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 32s 88ms/step - loss: 2.3783 - accuracy: 0.2999 - val_loss: 2.2548 - val_accuracy: 0.3076 - lr: 1.0000e-04
# Epoch 10/100
# 359/359 [==============================] - ETA: 0s - loss: 2.1473 - accuracy: 0.3241
# Epoch 10: val_loss improved from 2.25481 to 2.18143, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 32s 90ms/step - loss: 2.1473 - accuracy: 0.3241 - val_loss: 2.1814 - val_accuracy: 0.3059 - lr: 1.0000e-04
# Epoch 11/100
# 359/359 [==============================] - ETA: 0s - loss: 1.9723 - accuracy: 0.3582
# Epoch 11: val_loss improved from 2.18143 to 2.13723, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 33s 91ms/step - loss: 1.9723 - accuracy: 0.3582 - val_loss: 2.1372 - val_accuracy: 0.3278 - lr: 1.0000e-04
# Epoch 12/100
# 359/359 [==============================] - ETA: 0s - loss: 1.8481 - accuracy: 0.3914
# Epoch 12: val_loss improved from 2.13723 to 1.82506, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 32s 89ms/step - loss: 1.8481 - accuracy: 0.3914 - val_loss: 1.8251 - val_accuracy: 0.3909 - lr: 1.0000e-04
# Epoch 13/100
# 359/359 [==============================] - ETA: 0s - loss: 1.7474 - accuracy: 0.4194
# Epoch 13: val_loss improved from 1.82506 to 1.68063, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 33s 91ms/step - loss: 1.7474 - accuracy: 0.4194 - val_loss: 1.6806 - val_accuracy: 0.4470 - lr: 1.0000e-04
# Epoch 14/100
# 359/359 [==============================] - ETA: 0s - loss: 1.6654 - accuracy: 0.4458
# Epoch 14: val_loss did not improve from 1.68063
# 359/359 [==============================] - 31s 86ms/step - loss: 1.6654 - accuracy: 0.4458 - val_loss: 1.8633 - val_accuracy: 0.4029 - lr: 1.0000e-04
# Epoch 15/100
# 359/359 [==============================] - ETA: 0s - loss: 1.6095 - accuracy: 0.4634
# Epoch 15: val_loss improved from 1.68063 to 1.65176, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 32s 89ms/step - loss: 1.6095 - accuracy: 0.4634 - val_loss: 1.6518 - val_accuracy: 0.4450 - lr: 1.0000e-04
# Epoch 16/100
# 359/359 [==============================] - ETA: 0s - loss: 1.5614 - accuracy: 0.4794
# Epoch 16: val_loss improved from 1.65176 to 1.53894, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 32s 90ms/step - loss: 1.5614 - accuracy: 0.4794 - val_loss: 1.5389 - val_accuracy: 0.4701 - lr: 1.0000e-04
# Epoch 17/100
# 359/359 [==============================] - ETA: 0s - loss: 1.5181 - accuracy: 0.4958
# Epoch 17: val_loss improved from 1.53894 to 1.47200, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 37s 103ms/step - loss: 1.5181 - accuracy: 0.4958 - val_loss: 1.4720 - val_accuracy: 0.5125 - lr: 1.0000e-04
# Epoch 18/100
# 359/359 [==============================] - ETA: 0s - loss: 1.4863 - accuracy: 0.5088
# Epoch 18: val_loss did not improve from 1.47200
# 359/359 [==============================] - 31s 86ms/step - loss: 1.4863 - accuracy: 0.5088 - val_loss: 1.4809 - val_accuracy: 0.5018 - lr: 1.0000e-04
# Epoch 19/100
# 359/359 [==============================] - ETA: 0s - loss: 1.4665 - accuracy: 0.5090
# Epoch 19: val_loss improved from 1.47200 to 1.44207, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 33s 91ms/step - loss: 1.4665 - accuracy: 0.5090 - val_loss: 1.4421 - val_accuracy: 0.5159 - lr: 1.0000e-04
# Epoch 20/100
# 359/359 [==============================] - ETA: 0s - loss: 1.4327 - accuracy: 0.5211
# Epoch 20: val_loss did not improve from 1.44207
# 359/359 [==============================] - 32s 88ms/step - loss: 1.4327 - accuracy: 0.5211 - val_loss: 1.4498 - val_accuracy: 0.5057 - lr: 1.0000e-04
# Epoch 21/100
# 359/359 [==============================] - ETA: 0s - loss: 1.4209 - accuracy: 0.5243
# Epoch 21: val_loss did not improve from 1.44207
# 359/359 [==============================] - 31s 86ms/step - loss: 1.4209 - accuracy: 0.5243 - val_loss: 1.4487 - val_accuracy: 0.5057 - lr: 1.0000e-04
# Epoch 22/100
# 359/359 [==============================] - ETA: 0s - loss: 1.4031 - accuracy: 0.5310
# Epoch 22: val_loss improved from 1.44207 to 1.35939, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 37s 104ms/step - loss: 1.4031 - accuracy: 0.5310 - val_loss: 1.3594 - val_accuracy: 0.5490 - lr: 1.0000e-04
# Epoch 23/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3878 - accuracy: 0.5371
# Epoch 23: val_loss did not improve from 1.35939
# 359/359 [==============================] - 32s 88ms/step - loss: 1.3878 - accuracy: 0.5371 - val_loss: 1.3745 - val_accuracy: 0.5419 - lr: 1.0000e-04
# Epoch 24/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3723 - accuracy: 0.5391
# Epoch 24: val_loss did not improve from 1.35939
# 359/359 [==============================] - 32s 88ms/step - loss: 1.3723 - accuracy: 0.5391 - val_loss: 1.4544 - val_accuracy: 0.5024 - lr: 1.0000e-04
# Epoch 25/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3634 - accuracy: 0.5478
# Epoch 25: val_loss improved from 1.35939 to 1.34036, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 37s 102ms/step - loss: 1.3634 - accuracy: 0.5478 - val_loss: 1.3404 - val_accuracy: 0.5586 - lr: 1.0000e-04
# Epoch 26/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3479 - accuracy: 0.5545
# Epoch 26: val_loss did not improve from 1.34036
# 359/359 [==============================] - 31s 87ms/step - loss: 1.3479 - accuracy: 0.5545 - val_loss: 1.3702 - val_accuracy: 0.5431 - lr: 1.0000e-04
# Epoch 27/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3354 - accuracy: 0.5553
# Epoch 27: val_loss improved from 1.34036 to 1.32841, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 42s 117ms/step - loss: 1.3354 - accuracy: 0.5553 - val_loss: 1.3284 - val_accuracy: 0.5550 - lr: 1.0000e-04
# Epoch 28/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3285 - accuracy: 0.5575
# Epoch 28: val_loss did not improve from 1.32841
# 359/359 [==============================] - 32s 88ms/step - loss: 1.3285 - accuracy: 0.5575 - val_loss: 1.3288 - val_accuracy: 0.5550 - lr: 1.0000e-04
# Epoch 29/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3249 - accuracy: 0.5613
# Epoch 29: val_loss improved from 1.32841 to 1.32682, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 33s 90ms/step - loss: 1.3249 - accuracy: 0.5613 - val_loss: 1.3268 - val_accuracy: 0.5450 - lr: 1.0000e-04
# Epoch 30/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3101 - accuracy: 0.5633
# Epoch 30: val_loss did not improve from 1.32682
# 359/359 [==============================] - 33s 91ms/step - loss: 1.3101 - accuracy: 0.5633 - val_loss: 1.3572 - val_accuracy: 0.5461 - lr: 1.0000e-04
# Epoch 31/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3071 - accuracy: 0.5679
# Epoch 31: val_loss did not improve from 1.32682
# 359/359 [==============================] - 31s 86ms/step - loss: 1.3071 - accuracy: 0.5679 - val_loss: 1.3299 - val_accuracy: 0.5557 - lr: 1.0000e-04
# Epoch 32/100
# 359/359 [==============================] - ETA: 0s - loss: 1.2990 - accuracy: 0.5721
# Epoch 32: val_loss did not improve from 1.32682
# Restoring model weights from the end of the best epoch: 29.
# 359/359 [==============================] - 31s 87ms/step - loss: 1.2990 - accuracy: 0.5721 - val_loss: 1.3316 - val_accuracy: 0.5604 - lr: 1.0000e-04
# Epoch 32: early stopping

# %%
plot_training_history(history)

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 359/359 [==============================] - 21s 58ms/step - loss: 1.2739 - accuracy: 0.5764
# 113/113 [==============================] - 3s 24ms/step - loss: 1.2292 - accuracy: 0.5928
# final train accuracy = 57.64 , validation accuracy = 59.28

# %%
# Assuming your true_classes and predicted_classes are already defined
true_classes = test_generator.classes
predicted_classes = np.argmax(model.predict(test_generator, steps=np.ceil(test_generator.samples/test_generator.batch_size)), axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plotting with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 113/113 [==============================] - 3s 22ms/step

# %%
# Printing the classification report
report = classification_report(true_classes,
                               predicted_classes,
                               target_names=class_labels,
                               zero_division=0)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.14      0.04      0.06       958
#      disgust       0.00      0.00      0.00       111
#         fear       0.14      0.03      0.05      1024
#        happy       0.25      0.23      0.24      1774
#      neutral       0.17      0.23      0.19      1233
#          sad       0.18      0.35      0.24      1247
#     surprise       0.13      0.13      0.13       831
#
#     accuracy                           0.18      7178
#    macro avg       0.14      0.15      0.13      7178
# weighted avg       0.17      0.18      0.16      7178

# %% [markdown]
# # Model 3: Transfer Learning VGGNET

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Define paths to the train and validation directories
train_data_dir = 'D:/VS CODE/Notebook/Dataset/Emotion/train'
test_data_dir = 'D:/VS CODE/Notebook/Dataset/Emotion/test'

# validation_data_dir = '/content/emotion_detection_project/datasets/raw/test'

# Set some parameters
img_width, img_height = 224, 224  # Size of images
batch_size = 64
epochs = 10
num_classes = 7  # Update this based on the number of your classes

# Rescale the pixel values (0-255) to the [0, 1] interval
data_generator = ImageDataGenerator(
                                rescale = 1 / 255.,
                                rotation_range=10,
                                zoom_range=0.2,
                                width_shift_range=0.1,
                                height_shift_range=0.1,
                                horizontal_flip=True,
                                fill_mode='nearest',
                                # validation_split=0.2
                                )

test_preprocessor = ImageDataGenerator(
    rescale = 1 / 255.,
)

# Automatically retrieve images and their classes for train and validation sets
train_generator = data_generator.flow_from_directory(
                                train_data_dir,
                                target_size=(img_width, img_height),
                                batch_size=batch_size,
                                class_mode='categorical',
                                color_mode='rgb',
                                subset='training',
                                shuffle = True)

test_generator = test_preprocessor.flow_from_directory(
                                test_data_dir,
                                target_size=(img_width, img_height),
                                batch_size=batch_size,
                                class_mode='categorical',
                                color_mode='rgb',)
                                # subset='validation')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Extract class labels for all instances in the training dataset
classes = np.array(train_generator.classes)

# Calculate class weights to handle imbalances in the training data
# 'balanced' mode automatically adjusts weights inversely proportional to class frequencies
class_weights = compute_class_weight(
    class_weight='balanced',  # Strategy to balance classes
    classes=np.unique(classes),  # Unique class labels
    y=classes  # Class labels for each instance in the training dataset
)

# Create a dictionary mapping class indices to their calculated weights
class_weights_dict = dict(enumerate(class_weights))

# Output the class weights dictionary
print("Class Weights Dictionary:", class_weights_dict)
# Out:
# Class Weights Dictionary: {0: 1.0266046844269623, 1: 9.406618610747051, 2: 1.0010460615781582, 3: 0.5684387684387684, 4: 0.8260394187886635, 5: 0.8491274770777877, 6: 1.293372978330405}

# %%
classes = 7

# Clear the previous TensorFlow sessionx
tf.keras.backend.clear_session()

# Load the VGG16 base model, excluding its top (fully connected) layers
vgg = VGG16(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Make the specified layers non-trainable
for layer in vgg.layers[:-3]:
    layer.trainable = False

vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 4719616 (18.00 MB)
# Non-trainable params: 9995072 (38.13 MB)
# _________________________________________________________________

# %%
classes
# Out:
# 7

# %%
# Flattening the layer and adding custom Dense layers
x = Flatten()(vgg.output)

# Adding a fully connected layer with ReLU activation and He normal initializer
x = Dense(1024, activation='relu', kernel_initializer='he_normal')(x)
x = Dropout(0.5)(x)  # Adding dropout for regularization

x = Dense(512, activation='relu', kernel_initializer='he_normal')(x)
x = Dropout(0.5)(x)  # Adding dropout for regularization

# Adding the output layer with softmax activation
# Note: Adjust the number of units to match the number of classes you have
output = Dense(7, activation='softmax', kernel_initializer='he_normal')(x)

# Creating the model
model = Model(inputs=vgg.input, outputs=output)

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False),
              metrics=['accuracy'])

# Model summary to see all layers
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 40934215 (156.15 MB)
# Trainable params: 30939143 (118.02 MB)
# Non-trainable params: 9995072 (38.13 MB)
# _________________________________________________________________

# %%
# File path for the model checkpoint
cnn_path = '/D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/VGG16_Transfer_Learning'
name = 'VGG16_Transfer_Learning.keras'
chk_path = os.path.join(cnn_path, name)

# Callback to save the model checkpoint
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             monitor='val_loss')

# Callback for early stopping
earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True)

# Callback to reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=6,
                              verbose=1,
                              min_delta=0.0001)

# Callback to log training data to a CSV file
csv_logger = CSVLogger(os.path.join(cnn_path,'training.log'))

# Aggregating all callbacks into a list
callbacks = [checkpoint, earlystop, reduce_lr, csv_logger]  # Adjusted as per your use-case

train_steps_per_epoch = train_generator.samples // train_generator.batch_size + 1
# validation_steps_epoch = validation_generator.samples // validation_generator.batch_size + 1
test_steps_epoch = test_generator.samples // test_generator.batch_size + 1

# %%
history = model.fit(
                    train_generator,
                    steps_per_epoch=train_steps_per_epoch,
                    epochs=50,
                    validation_data=test_generator,
                    validation_steps=test_steps_epoch,
                    class_weight=class_weights_dict,
                    callbacks = callbacks
                    )
# Out:
# Epoch 1/50
# 449/449 [==============================] - ETA: 0s - loss: 1.8374 - accuracy: 0.2601
# Epoch 1: val_loss improved from inf to 1.47277, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 436s 933ms/step - loss: 1.8374 - accuracy: 0.2601 - val_loss: 1.4728 - val_accuracy: 0.4401 - lr: 1.0000e-04
# Epoch 2/50
# 449/449 [==============================] - ETA: 0s - loss: 1.6075 - accuracy: 0.3841
# Epoch 2: val_loss improved from 1.47277 to 1.39369, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 433s 963ms/step - loss: 1.6075 - accuracy: 0.3841 - val_loss: 1.3937 - val_accuracy: 0.4698 - lr: 1.0000e-04
# Epoch 3/50
# 449/449 [==============================] - ETA: 0s - loss: 1.4904 - accuracy: 0.4273
# Epoch 3: val_loss did not improve from 1.39369
# 449/449 [==============================] - 419s 934ms/step - loss: 1.4904 - accuracy: 0.4273 - val_loss: 1.4036 - val_accuracy: 0.4588 - lr: 1.0000e-04
# Epoch 4/50
# 449/449 [==============================] - ETA: 0s - loss: 1.4194 - accuracy: 0.4539
# Epoch 4: val_loss improved from 1.39369 to 1.37222, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 431s 959ms/step - loss: 1.4194 - accuracy: 0.4539 - val_loss: 1.3722 - val_accuracy: 0.4780 - lr: 1.0000e-04
# Epoch 5/50
# 449/449 [==============================] - ETA: 0s - loss: 1.3552 - accuracy: 0.4765
# Epoch 5: val_loss improved from 1.37222 to 1.32786, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 434s 966ms/step - loss: 1.3552 - accuracy: 0.4765 - val_loss: 1.3279 - val_accuracy: 0.4921 - lr: 1.0000e-04
# Epoch 6/50
# 449/449 [==============================] - ETA: 0s - loss: 1.3060 - accuracy: 0.4932
# Epoch 6: val_loss improved from 1.32786 to 1.22642, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 424s 944ms/step - loss: 1.3060 - accuracy: 0.4932 - val_loss: 1.2264 - val_accuracy: 0.5301 - lr: 1.0000e-04
# Epoch 7/50
# 449/449 [==============================] - ETA: 0s - loss: 1.2656 - accuracy: 0.5088
# Epoch 7: val_loss improved from 1.22642 to 1.20169, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 434s 966ms/step - loss: 1.2656 - accuracy: 0.5088 - val_loss: 1.2017 - val_accuracy: 0.5401 - lr: 1.0000e-04
# Epoch 8/50
# 449/449 [==============================] - ETA: 0s - loss: 1.2326 - accuracy: 0.5152
# Epoch 8: val_loss improved from 1.20169 to 1.15415, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 432s 961ms/step - loss: 1.2326 - accuracy: 0.5152 - val_loss: 1.1542 - val_accuracy: 0.5500 - lr: 1.0000e-04
# Epoch 9/50
# 449/449 [==============================] - ETA: 0s - loss: 1.2030 - accuracy: 0.5319
# Epoch 9: val_loss did not improve from 1.15415
# 449/449 [==============================] - 441s 982ms/step - loss: 1.2030 - accuracy: 0.5319 - val_loss: 1.1635 - val_accuracy: 0.5581 - lr: 1.0000e-04
# Epoch 10/50
# 449/449 [==============================] - ETA: 0s - loss: 1.1703 - accuracy: 0.5375
# Epoch 10: val_loss did not improve from 1.15415
# 449/449 [==============================] - 423s 941ms/step - loss: 1.1703 - accuracy: 0.5375 - val_loss: 1.1734 - val_accuracy: 0.5520 - lr: 1.0000e-04
# Epoch 11/50
# 449/449 [==============================] - ETA: 0s - loss: 1.1469 - accuracy: 0.5472
# Epoch 11: val_loss did not improve from 1.15415
# Restoring model weights from the end of the best epoch: 8.
# 449/449 [==============================] - 425s 946ms/step - loss: 1.1469 - accuracy: 0.5472 - val_loss: 1.1745 - val_accuracy: 0.5550 - lr: 1.0000e-04
# Epoch 11: early stopping

# %%
plot_training_history(history)

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 449/449 [==============================] - 401s 893ms/step - loss: 1.1518 - accuracy: 0.5593
# 113/113 [==============================] - 29s 257ms/step - loss: 1.1542 - accuracy: 0.5500
# final train accuracy = 55.93 , validation accuracy = 55.00

# %%
# Assuming your true_classes and predicted_classes are already defined
true_classes = test_generator.classes
predicted_classes = np.argmax(model.predict(test_generator, steps=np.ceil(test_generator.samples/test_generator.batch_size)), axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plotting with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 113/113 [==============================] - 28s 250ms/step

# %%
# Printing the classification report
report = classification_report(true_classes,
                               predicted_classes,
                               target_names=class_labels,
                               zero_division=0)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.15      0.14      0.14       958
#      disgust       0.02      0.04      0.02       111
#         fear       0.13      0.06      0.08      1024
#        happy       0.25      0.29      0.27      1774
#      neutral       0.17      0.24      0.20      1233
#          sad       0.17      0.11      0.13      1247
#     surprise       0.12      0.13      0.12       831
#
#     accuracy                           0.17      7178
#    macro avg       0.14      0.14      0.14      7178
# weighted avg       0.17      0.17      0.17      7178

# %% [markdown]
# # Model 4 : Transfer Leanring - ResNet50

# %%
# Directory paths for training and testing data
import os
train_dir = 'D:/VS CODE/Python/Notebook/Dataset/Emotion/train'
test_dir = 'D:/VS CODE/Python/Notebook/Dataset/Emotion/test'
# Batch size for data generators
batch_size = 64

# Data augmentation configuration for training data
train_datagen = ImageDataGenerator(
                                  rescale=1 / 255.,  # Rescale pixel values to [0,1]
                                  rotation_range=10,  # Random rotation within range [-10,10] degrees
                                  zoom_range=0.2,  # Random zoom between [0.8, 1.2]
                                  width_shift_range=0.1,  # Random horizontal shift within range [-0.1, 0.1]
                                  height_shift_range=0.1,  # Random vertical shift within range [-0.1, 0.1]
                                  horizontal_flip=True,  # Random horizontal flip
                                  fill_mode='nearest'  # Fill mode for handling newly created pixels
                                 )

# Configuration for testing data (only rescaling)
test_datagen = ImageDataGenerator(
                                  rescale=1 / 255.  # Rescale pixel values to [0,1]
                                 )

# Data generators for training and testing data
train_generator = train_datagen.flow_from_directory(
                                                    train_dir,  # Directory containing training data
                                                    class_mode="categorical",  # Classification mode for categorical labels
                                                    target_size=(224, 224),  # Resize input images to (224,224)
                                                    color_mode='rgb',  # Color mode for images (RGB)
                                                    shuffle=True,  # Shuffle training data
                                                    batch_size=batch_size,  # Batch size for training
                                                    subset='training'  # Subset of data (training)
                                                   )

test_generator = test_datagen.flow_from_directory(
                                                  test_dir,  # Directory containing testing data
                                                  class_mode="categorical",  # Classification mode for categorical labels
                                                  target_size=(224, 224),  # Resize input images to (224,224)
                                                  color_mode="rgb",  # Color mode for images (RGB)
                                                  shuffle=False,  # Do not shuffle testing data
                                                  batch_size=batch_size  # Batch size for testing
                                                 )
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # Introducing Class wieghts for imbalanced data

# %%
# Extract class labels for all instances in the training dataset
classes = np.array(train_generator.classes)

# Calculate class weights to handle imbalances in the training data
# 'balanced' mode automatically adjusts weights inversely proportional to class frequencies
class_weights = compute_class_weight(
    class_weight='balanced',  # Strategy to balance classes
    classes=np.unique(classes),  # Unique class labels
    y=classes  # Class labels for each instance in the training dataset
)

# Create a dictionary mapping class indices to their calculated weights
class_weights_dict = dict(enumerate(class_weights))

# Output the class weights dictionary
print("Class Weights Dictionary:", class_weights_dict)
# Out:
# Class Weights Dictionary: {0: 1.0266046844269623, 1: 9.406618610747051, 2: 1.0010460615781582, 3: 0.5684387684387684, 4: 0.8260394187886635, 5: 0.8491274770777877, 6: 1.293372978330405}

# %%
ResNet50V2 = tf.keras.applications.ResNet50V2(input_shape=(224, 224, 3),
                                               include_top= False,
                                               weights='imagenet'
                                               )
# Out:
# WARNING:tensorflow:From c:\Users\tanma\anaconda3\envs\emenv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\tanma\anaconda3\envs\emenv\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# Freezing all layers except last 50

ResNet50V2.trainable = True

for layer in ResNet50V2.layers[:-50]:
    layer.trainable = False

# %%
def Create_ResNet50V2_Model():

    model = Sequential([
                      ResNet50V2,
                      Dropout(0.25),
                      BatchNormalization(),
                      Flatten(),
                      Dense(64, activation='relu'),
                      BatchNormalization(),
                      Dropout(0.5),
                      Dense(7,activation='softmax')
                    ])
    return model

# %%
model = Create_ResNet50V2_Model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  dropout (Dropout)           (None, 7, 7, 2048)        0
#
#  batch_normalization (Batch  (None, 7, 7, 2048)        8192
#  Normalization)
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 64)                6422592
#
#  batch_normalization_1 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 29996295 (114.43 MB)
# Trainable params: 22779527 (86.90 MB)
# Non-trainable params: 7216768 (27.53 MB)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\tanma\anaconda3\envs\emenv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
import scipy
# File path for the model checkpoint
cnn_path = 'D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning'
name = 'ResNet50_Transfer_Learning.keras'
chk_path = os.path.join(cnn_path, name)

# Callback to save the model checkpoint
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             monitor='val_loss')

# Callback for early stopping
earlystop = EarlyStopping(monitor = 'val_accuracy',
                          patience = 7,
                          restore_best_weights = True,
                          verbose=1)

# Callback to reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=2,
#                             min_lr=0.00005,
                              verbose=1)

# Callback to log training data to a CSV file
csv_logger = CSVLogger(os.path.join(cnn_path,'training.log'))

# Aggregating all callbacks into a list
callbacks = [checkpoint, earlystop, csv_logger]  # Adjusted as per your use-case

train_steps_per_epoch = train_generator.samples // train_generator.batch_size + 1
# validation_steps_epoch = validation_generator.samples // validation_generator.batch_size + 1
test_steps_epoch = test_generator.samples // test_generator.batch_size + 1

# %%
pip install scikit-learn scipy
# Out:
# Requirement already satisfied: scikit-learn in c:\users\tanma\anaconda3\envs\emenv\lib\site-packages (1.5.1)
# Requirement already satisfied: scipy in c:\users\tanma\anaconda3\envs\emenv\lib\site-packages (1.14.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\tanma\anaconda3\envs\emenv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tanma\anaconda3\envs\emenv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tanma\anaconda3\envs\emenv\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
train_history = model.fit(
                          train_generator,
                          steps_per_epoch=train_steps_per_epoch,
                          epochs=30,
                          validation_data=test_generator,
                          validation_steps=test_steps_epoch,
                          class_weight=class_weights_dict,
                          callbacks = callbacks
                         )
# Out:
# Epoch 1/30
# WARNING:tensorflow:From c:\Users\tanma\anaconda3\envs\emenv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\tanma\anaconda3\envs\emenv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 449/449 [==============================] - ETA: 0s - loss: 1.8774 - accuracy: 0.3571
# Epoch 1: val_loss improved from inf to 4.81031, saving model to D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 [==============================] - 2434s 5s/step - loss: 1.8774 - accuracy: 0.3571 - val_loss: 4.8103 - val_accuracy: 0.3866
# Epoch 2/30
# 449/449 [==============================] - ETA: 0s - loss: 1.4460 - accuracy: 0.4584
# Epoch 2: val_loss improved from 4.81031 to 1.39384, saving model to D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 [==============================] - 2272s 5s/step - loss: 1.4460 - accuracy: 0.4584 - val_loss: 1.3938 - val_accuracy: 0.4788
# Epoch 3/30
# 449/449 [==============================] - ETA: 0s - loss: 1.3384 - accuracy: 0.5025
# Epoch 3: val_loss improved from 1.39384 to 1.22748, saving model to D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 [==============================] - 2247s 5s/step - loss: 1.3384 - accuracy: 0.5025 - val_loss: 1.2275 - val_accuracy: 0.5529
# Epoch 4/30
# 449/449 [==============================] - ETA: 0s - loss: 1.2314 - accuracy: 0.5410
# Epoch 4: val_loss improved from 1.22748 to 1.13946, saving model to D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 [==============================] - 2982s 7s/step - loss: 1.2314 - accuracy: 0.5410 - val_loss: 1.1395 - val_accuracy: 0.5677
# Epoch 5/30
# 449/449 [==============================] - ETA: 0s - loss: 1.2062 - accuracy: 0.5523
# Epoch 5: val_loss did not improve from 1.13946
# 449/449 [==============================] - 2282s 5s/step - loss: 1.2062 - accuracy: 0.5523 - val_loss: 3.3198 - val_accuracy: 0.3668
# Epoch 6/30
# 449/449 [==============================] - ETA: 0s - loss: 1.1683 - accuracy: 0.5636
# Epoch 6: val_loss improved from 1.13946 to 1.09066, saving model to D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 [==============================] - 2115s 5s/step - loss: 1.1683 - accuracy: 0.5636 - val_loss: 1.0907 - val_accuracy: 0.5961
# Epoch 7/30
# 449/449 [==============================] - ETA: 0s - loss: 1.0990 - accuracy: 0.5861
# Epoch 7: val_loss improved from 1.09066 to 1.08532, saving model to D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 [==============================] - 2130s 5s/step - loss: 1.0990 - accuracy: 0.5861 - val_loss: 1.0853 - val_accuracy: 0.5989
# Epoch 8/30
# 449/449 [==============================] - ETA: 0s - loss: 1.0898 - accuracy: 0.5887
# Epoch 8: val_loss did not improve from 1.08532
# 449/449 [==============================] - 2452s 5s/step - loss: 1.0898 - accuracy: 0.5887 - val_loss: 1.1694 - val_accuracy: 0.5691
# Epoch 9/30
# 449/449 [==============================] - ETA: 0s - loss: 1.0547 - accuracy: 0.6014
# Epoch 9: val_loss did not improve from 1.08532
# 449/449 [==============================] - 2440s 5s/step - loss: 1.0547 - accuracy: 0.6014 - val_loss: 1.1283 - val_accuracy: 0.5954
# Epoch 10/30
# 449/449 [==============================] - ETA: 0s - loss: 1.0261 - accuracy: 0.6133
# Epoch 10: val_loss did not improve from 1.08532
# 449/449 [==============================] - 2107s 5s/step - loss: 1.0261 - accuracy: 0.6133 - val_loss: 1.1024 - val_accuracy: 0.6043
# Epoch 11/30
# 449/449 [==============================] - ETA: 0s - loss: 1.0106 - accuracy: 0.6156
# Epoch 11: val_loss improved from 1.08532 to 1.07438, saving model to D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 [==============================] - 2449s 5s/step - loss: 1.0106 - accuracy: 0.6156 - val_loss: 1.0744 - val_accuracy: 0.5978
# Epoch 12/30
# 449/449 [==============================] - ETA: 0s - loss: 0.9977 - accuracy: 0.6193
# Epoch 12: val_loss did not improve from 1.07438
# 449/449 [==============================] - 2111s 5s/step - loss: 0.9977 - accuracy: 0.6193 - val_loss: 1.0984 - val_accuracy: 0.6037
# Epoch 13/30
# 449/449 [==============================] - ETA: 0s - loss: 0.9679 - accuracy: 0.6326
# Epoch 13: val_loss improved from 1.07438 to 1.05877, saving model to D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 [==============================] - 2112s 5s/step - loss: 0.9679 - accuracy: 0.6326 - val_loss: 1.0588 - val_accuracy: 0.6134
# Epoch 14/30
# 449/449 [==============================] - ETA: 0s - loss: 0.9490 - accuracy: 0.6347
# Epoch 14: val_loss improved from 1.05877 to 0.98348, saving model to D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 [==============================] - 2112s 5s/step - loss: 0.9490 - accuracy: 0.6347 - val_loss: 0.9835 - val_accuracy: 0.6296
# Epoch 15/30
# 449/449 [==============================] - ETA: 0s - loss: 0.9552 - accuracy: 0.6297
# Epoch 15: val_loss did not improve from 0.98348
# 449/449 [==============================] - 2114s 5s/step - loss: 0.9552 - accuracy: 0.6297 - val_loss: 1.0000 - val_accuracy: 0.6307
# Epoch 16/30
# 449/449 [==============================] - ETA: 0s - loss: 0.9338 - accuracy: 0.6383
# Epoch 16: val_loss did not improve from 0.98348
# 449/449 [==============================] - 2108s 5s/step - loss: 0.9338 - accuracy: 0.6383 - val_loss: 1.0240 - val_accuracy: 0.6283
# Epoch 17/30
# 449/449 [==============================] - ETA: 0s - loss: 0.9255 - accuracy: 0.6451
# Epoch 17: val_loss did not improve from 0.98348
# 449/449 [==============================] - 2106s 5s/step - loss: 0.9255 - accuracy: 0.6451 - val_loss: 1.8539 - val_accuracy: 0.5613
# Epoch 18/30
# 449/449 [==============================] - ETA: 0s - loss: 0.9301 - accuracy: 0.6421
# Epoch 18: val_loss did not improve from 0.98348
# 449/449 [==============================] - 2102s 5s/step - loss: 0.9301 - accuracy: 0.6421 - val_loss: 0.9840 - val_accuracy: 0.6395
# Epoch 19/30
# 449/449 [==============================] - ETA: 0s - loss: 0.8791 - accuracy: 0.6571
# Epoch 19: val_loss did not improve from 0.98348
# 449/449 [==============================] - 2065s 5s/step - loss: 0.8791 - accuracy: 0.6571 - val_loss: 1.0152 - val_accuracy: 0.6365
# Epoch 20/30
# 449/449 [==============================] - ETA: 0s - loss: 0.8715 - accuracy: 0.6624
# Epoch 20: val_loss improved from 0.98348 to 0.97074, saving model to D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 [==============================] - 2176s 5s/step - loss: 0.8715 - accuracy: 0.6624 - val_loss: 0.9707 - val_accuracy: 0.6388
# Epoch 21/30
# 449/449 [==============================] - ETA: 0s - loss: 0.8611 - accuracy: 0.6645
# Epoch 21: val_loss did not improve from 0.97074
# 449/449 [==============================] - 2136s 5s/step - loss: 0.8611 - accuracy: 0.6645 - val_loss: 1.0124 - val_accuracy: 0.6298
# Epoch 22/30
# 449/449 [==============================] - ETA: 0s - loss: 0.8615 - accuracy: 0.6659
# Epoch 22: val_loss did not improve from 0.97074
# 449/449 [==============================] - 2085s 5s/step - loss: 0.8615 - accuracy: 0.6659 - val_loss: 1.0405 - val_accuracy: 0.6204
# Epoch 23/30
# 449/449 [==============================] - ETA: 0s - loss: 0.8338 - accuracy: 0.6747
# Epoch 23: val_loss did not improve from 0.97074
# 449/449 [==============================] - 2056s 5s/step - loss: 0.8338 - accuracy: 0.6747 - val_loss: 1.0545 - val_accuracy: 0.6167
# Epoch 24/30
# 449/449 [==============================] - ETA: 0s - loss: 0.8225 - accuracy: 0.6801
# Epoch 24: val_loss improved from 0.97074 to 0.95305, saving model to D:/VS CODE/Notebook/Dataset/Emotion/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning\ResNet50_Transfer_Learning.keras
# 449/449 [==============================] - 2453s 5s/step - loss: 0.8225 - accuracy: 0.6801 - val_loss: 0.9530 - val_accuracy: 0.6577
# Epoch 25/30
# 449/449 [==============================] - ETA: 0s - loss: 0.8397 - accuracy: 0.6745
# Epoch 25: val_loss did not improve from 0.95305
# 449/449 [==============================] - 2499s 6s/step - loss: 0.8397 - accuracy: 0.6745 - val_loss: 0.9924 - val_accuracy: 0.6421
# Epoch 26/30
# 449/449 [==============================] - ETA: 0s - loss: 0.8180 - accuracy: 0.6834
# Epoch 26: val_loss did not improve from 0.95305
# 449/449 [==============================] - 2353s 5s/step - loss: 0.8180 - accuracy: 0.6834 - val_loss: 0.9593 - val_accuracy: 0.6510
# Epoch 27/30
# 449/449 [==============================] - ETA: 0s - loss: 0.8141 - accuracy: 0.6856
# Epoch 27: val_loss did not improve from 0.95305
# 449/449 [==============================] - 2085s 5s/step - loss: 0.8141 - accuracy: 0.6856 - val_loss: 1.0484 - val_accuracy: 0.6287
# Epoch 28/30
# 449/449 [==============================] - ETA: 0s - loss: 0.8181 - accuracy: 0.6817
# Epoch 28: val_loss did not improve from 0.95305
# 449/449 [==============================] - 2126s 5s/step - loss: 0.8181 - accuracy: 0.6817 - val_loss: 1.0470 - val_accuracy: 0.6361
# Epoch 29/30
# 449/449 [==============================] - ETA: 0s - loss: 0.7807 - accuracy: 0.6970
# Epoch 29: val_loss did not improve from 0.95305
# 449/449 [==============================] - 2518s 6s/step - loss: 0.7807 - accuracy: 0.6970 - val_loss: 1.1276 - val_accuracy: 0.6067
# Epoch 30/30
# 449/449 [==============================] - ETA: 0s - loss: 0.7758 - accuracy: 0.6959
# Epoch 30: val_loss did not improve from 0.95305
# 449/449 [==============================] - 2518s 6s/step - loss: 0.7758 - accuracy: 0.6959 - val_loss: 1.0551 - val_accuracy: 0.6393

# %%
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import keras

# %%
# model = keras.saving.load_model("/content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras")

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 449/449 [==============================] - 1244s 3s/step - loss: 0.8300 - accuracy: 0.6985
# 113/113 [==============================] - 297s 3s/step - loss: 1.0551 - accuracy: 0.6393
# final train accuracy = 69.85 , validation accuracy = 63.93

# %%
# Assuming your true_classes and predicted_classes are already defined
true_classes = test_generator.classes
predicted_classes = np.argmax(model.predict(test_generator, steps=np.ceil(test_generator.samples/test_generator.batch_size)), axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plotting with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 113/113 [==============================] - 20s 171ms/step

# %%
# Printing the classification report
report = classification_report(true_classes,
                               predicted_classes,
                               target_names=class_labels,
                               zero_division=0)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.54      0.57      0.55       958
#      disgust       0.57      0.61      0.59       111
#         fear       0.43      0.37      0.40      1024
#        happy       0.89      0.79      0.84      1774
#      neutral       0.53      0.63      0.58      1233
#          sad       0.55      0.39      0.46      1247
#     surprise       0.56      0.84      0.67       831
#
#     accuracy                           0.61      7178
#    macro avg       0.58      0.60      0.58      7178
# weighted avg       0.61      0.61      0.60      7178

# %% [markdown]
# # AUC ROC plot for each class

# %%
true_labels = test_generator.classes
preds = model.predict(test_generator, steps=len(test_generator))
pred_labels = np.argmax(preds, axis=1)
classes=list(test_generator.class_indices.keys())
# Out:
# 113/113 [==============================] - 19s 166ms/step

# %%
y_encoded = pd.get_dummies(true_labels).astype(int).values
preds_encoded = pd.get_dummies(pred_labels).astype(int).values

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_encoded[:,i], preds_encoded[:,i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10,5))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2']
for i, color in enumerate(colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f"ROC curve for {classes[i]} (area = {roc_auc[i]:0.2f})")

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')

# %%
model.save("Resnet_model_version_2.keras")

# %% [markdown]
# # Push all your models into Drive for easy access.

# %%
# !cp /content/FER_2013_Emotion_Detection /content/drive/MyDrive/

# %% [markdown]
# ## If you are here and followed and learned everything, you are in a great positon to build a project at a industry standard level. Kudos to you!!
# ## All that's left is Deployement

# %% [markdown]
# # Deployement

# %% [markdown]
# # Gradio

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install gradio

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import gradio as gr
import gradio as gr
import tensorflow as tf
import numpy as np
from PIL import Image
import cv2
from tensorflow.keras.preprocessing import image

# %%
# Ensure your model is loaded here
# model = ... # Load your trained model
# Load your pre-trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/Emotion_Detection/Final_Resnet50_Best_model.keras')

# %%
# Emotion labels dictionary
emotion_labels = {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
index_to_emotion = {v: k for k, v in emotion_labels.items()}
index_to_emotion
# Out:
# {0: 'angry',
#  1: 'disgust',
#  2: 'fear',
#  3: 'happy',
#  4: 'neutral',
#  5: 'sad',
#  6: 'surprise'}

# %%
def prepare_image(img_pil):
    """Preprocess the PIL image to fit your model's input requirements."""
    # Convert the PIL image to a numpy array with the target size
    img = img_pil.resize((224, 224))
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Convert single image to a batch.
    img_array /= 255.0  # Rescale pixel values to [0,1], as done during training
    return img_array



# Define the Gradio interface
def predict_emotion(image):
    # Preprocess the image
    processed_image = prepare_image(image)
    # Make prediction using the model
    prediction = model.predict(processed_image)
    # Get the emotion label with the highest probability
    predicted_class = np.argmax(prediction, axis=1)
    predicted_emotion = index_to_emotion.get(predicted_class[0], "Unknown Emotion")
    return predicted_emotion

interface = gr.Interface(
    fn=predict_emotion,  # Your prediction function
    inputs=gr.Image(type="pil"),  # Input for uploading an image, directly compatible with PIL images
    outputs="text",  # Output as text displaying the predicted emotion
    title="Emotion Detection",
    description="Upload an image and see the predicted emotion."
)

# Launch the Gradio interface
interface.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://eb53f8c30e2eca7f49.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://eb53f8c30e2eca7f49.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
